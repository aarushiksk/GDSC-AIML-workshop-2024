# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\aarus\\Downloads\\archive\\student_data.csv")

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# # For the sake of ease i have taken only 7 columns
# - sex
# - age
# - address
# - Medu
# - Fedu
# - G1
# - G2

# %% [markdown]
# # Target Variable is the value that we have to find

# %%
df2=df[['sex','age','address','Medu','Fedu','G1','G2','G3']]

# %%
df2
# Out:
#     sex  age address  Medu  Fedu  G1  G2  G3
# 0     F   18       U     4     4   5   6   6
# 1     F   17       U     1     1   5   5   6
# 2     F   15       U     1     1   7   8  10
# 3     F   15       U     4     2  15  14  15
# 4     F   16       U     3     3   6  10  10
# ..   ..  ...     ...   ...   ...  ..  ..  ..
# 390   M   20       U     2     2   9   9   9
# 391   M   17       U     3     1  14  16  16
# 392   M   21       R     1     1  10   8   7
# 393   M   18       R     3     2  11  12  10
# 394   M   19       U     1     1   8   9   9
#
# [395 rows x 8 columns]

# %% [markdown]
# #### Show how to properly understand the dataset

# %%
df2.shape
# Out:
# (395, 8)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sex      395 non-null    object
#  1   age      395 non-null    int64
#  2   address  395 non-null    object
#  3   Medu     395 non-null    int64
#  4   Fedu     395 non-null    int64
#  5   G1       395 non-null    int64
#  6   G2       395 non-null    int64
#  7   G3       395 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 24.8+ KB

# %%
df2.describe()
# Out:
#               age        Medu        Fedu          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519   10.908861   10.713924   10.415190
# std      1.276043    1.094735    1.088201    3.319195    3.761505    4.581443
# min     15.000000    0.000000    0.000000    3.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000    8.000000    9.000000    8.000000
# 50%     17.000000    3.000000    2.000000   11.000000   11.000000   11.000000
# 75%     18.000000    4.000000    3.000000   13.000000   13.000000   14.000000
# max     22.000000    4.000000    4.000000   19.000000   19.000000   20.000000

# %%
df2.sample(5)
# Out:
#     sex  age address  Medu  Fedu  G1  G2  G3
# 144   M   17       U     2     1   5   0   0
# 87    F   15       U     4     2  13  14  14
# 113   M   15       U     4     2  18  19  19
# 248   M   18       R     3     3   3   5   5
# 348   F   17       U     4     3  13  15  15

# %%
df['address'].value_counts()
# Out:
# address
# U    307
# R     88
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# F    208
# M    187
# Name: count, dtype: int64

# %%
df['Medu'].value_counts()
# Out:
# Medu
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: count, dtype: int64

# %% [markdown]
# # Preprocessing Steps

# %% [markdown]
# # Get Dummies

# %%
df_encoded=pd.get_dummies(df['sex'],prefix='sex')

# %%
df_encoded
# Out:
#      sex_F  sex_M
# 0     True  False
# 1     True  False
# 2     True  False
# 3     True  False
# 4     True  False
# ..     ...    ...
# 390  False   True
# 391  False   True
# 392  False   True
# 393  False   True
# 394  False   True
#
# [395 rows x 2 columns]

# %%
df2=pd.concat([df2,df_encoded],axis=1)

# %%
df_encoded=pd.get_dummies(df['address'],prefix='address')
df2=pd.concat([df2,df_encoded],axis=1)

# %%
df2
# Out:
#     sex  age address  Medu  Fedu  G1  G2  G3  sex_F  sex_M  address_R  \
# 0     F   18       U     4     4   5   6   6   True  False      False
# 1     F   17       U     1     1   5   5   6   True  False      False
# 2     F   15       U     1     1   7   8  10   True  False      False
# 3     F   15       U     4     2  15  14  15   True  False      False
# 4     F   16       U     3     3   6  10  10   True  False      False
# ..   ..  ...     ...   ...   ...  ..  ..  ..    ...    ...        ...
# 390   M   20       U     2     2   9   9   9  False   True      False
# 391   M   17       U     3     1  14  16  16  False   True      False
# 392   M   21       R     1     1  10   8   7  False   True       True
# 393   M   18       R     3     2  11  12  10  False   True       True
# 394   M   19       U     1     1   8   9   9  False   True      False
#
#      address_U
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ..         ...
# ...

# %%
X=df2.drop(columns=['sex','address'])

# %%
X=X.astype('int')

# %%
X
# Out:
#      age  Medu  Fedu  G1  G2  G3  sex_F  sex_M  address_R  address_U
# 0     18     4     4   5   6   6      1      0          0          1
# 1     17     1     1   5   5   6      1      0          0          1
# 2     15     1     1   7   8  10      1      0          0          1
# 3     15     4     2  15  14  15      1      0          0          1
# 4     16     3     3   6  10  10      1      0          0          1
# ..   ...   ...   ...  ..  ..  ..    ...    ...        ...        ...
# 390   20     2     2   9   9   9      0      1          0          1
# 391   17     3     1  14  16  16      0      1          0          1
# 392   21     1     1  10   8   7      0      1          1          0
# 393   18     3     2  11  12  10      0      1          1          0
# 394   19     1     1   8   9   9      0      1          0          1
#
# [395 rows x 10 columns]

# %%
df['Medu'].value_counts()
# Out:
# Medu
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: count, dtype: int64

# %% [markdown]
# # Visualisations

# %%
sns.barplot(x=df['sex'],y=df['G1'],data=df)
# Out:
# <Axes: xlabel='sex', ylabel='G1'>

# %%
sns.lineplot(x=df['age'], y=df['G2'])
# Out:
# <Axes: xlabel='age', ylabel='G2'>

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.lineplot(x=df['G1'],y=df['G3'])
# Out:
# <Axes: xlabel='G1', ylabel='G3'>

# %%
custom_palette = sns.color_palette("Set2") 
sns.countplot(x=df['address'],hue=df['G3'],palette=custom_palette)
# Out:
# C:\Users\aarus\AppData\Local\Temp\ipykernel_13868\3860591678.py:2: UserWarning:
# The palette list has fewer values (8) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x=df['address'],hue=df['G3'],palette=custom_palette)
# <Axes: xlabel='address', ylabel='count'>

# %%
df2
# Out:
#     sex  age address  Medu  Fedu  G1  G2  G3  sex_F  sex_M  address_R  \
# 0     F   18       U     4     4   5   6   6   True  False      False
# 1     F   17       U     1     1   5   5   6   True  False      False
# 2     F   15       U     1     1   7   8  10   True  False      False
# 3     F   15       U     4     2  15  14  15   True  False      False
# 4     F   16       U     3     3   6  10  10   True  False      False
# ..   ..  ...     ...   ...   ...  ..  ..  ..    ...    ...        ...
# 390   M   20       U     2     2   9   9   9  False   True      False
# 391   M   17       U     3     1  14  16  16  False   True      False
# 392   M   21       R     1     1  10   8   7  False   True       True
# 393   M   18       R     3     2  11  12  10  False   True       True
# 394   M   19       U     1     1   8   9   9  False   True      False
#
#      address_U
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ..         ...
# ...

# %% [markdown]
# # Model Making

# %%
X=df2.drop(columns=['sex','address','G3'])
X=X.astype('int')

Y=df2['G3']

# %%
X
# Out:
#      age  Medu  Fedu  G1  G2  sex_F  sex_M  address_R  address_U
# 0     18     4     4   5   6      1      0          0          1
# 1     17     1     1   5   5      1      0          0          1
# 2     15     1     1   7   8      1      0          0          1
# 3     15     4     2  15  14      1      0          0          1
# 4     16     3     3   6  10      1      0          0          1
# ..   ...   ...   ...  ..  ..    ...    ...        ...        ...
# 390   20     2     2   9   9      0      1          0          1
# 391   17     3     1  14  16      0      1          0          1
# 392   21     1     1  10   8      0      1          1          0
# 393   18     3     2  11  12      0      1          1          0
# 394   19     1     1   8   9      0      1          0          1
#
# [395 rows x 9 columns]

# %%
Y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([ 3.83177002,  8.25857871,  6.18645752,  5.18915826, 10.55692629,
#         4.14205411, 13.3586654 , 15.56237616,  9.79499845,  9.96579488,
#        18.46669711,  7.42035594, 12.22536722,  8.99392097, 13.0527614 ,
#        12.8017683 ,  5.0126649 , 16.65415324, 14.36490894,  4.8365614 ,
#         8.05103111, 14.90691487, 10.51155028, 16.23236371, 19.26115068,
#        12.8614024 ,  4.09765182,  7.7705269 , 14.06043396, 18.40379197,
#        13.00835911,  5.07411788,  8.75573379,  9.43028181, 14.22845473,
#        11.76976064, -0.64477552, 11.59751205,  9.83794858,  8.25920941,
#        13.45264172, 18.71185796,  5.44028668,  9.20991135,  9.36658501,
#         7.91830508, 15.42268072, 10.76882417,  6.13917406,  0.18436339,
#         8.4742728 ,  8.9819091 , 14.11198533, 12.74794951,  6.89783086,
#        16.69514917, 15.17313978,  9.36124814, -1.1787011 , 10.48010618,
#        11.28833701,  8.39745269, 14.50328755, 12.04324682,  9.3455441 ,
# ...

# %%
mse=mean_squared_error(Y_test,y_pred)
mse
# Out:
# 2.5278843715300883

# %%
from sklearn.metrics import r2_score
r2=r2_score(Y_test,y_pred)
r2
# Out:
# 0.8713506559240713

# %%
model.score(X_test,Y_test)
# Out:
# 0.8713506559240713

# %%
import joblib
joblib.dump(model, 'linear_regression_model.pkl')
# Out:
# ['linear_regression_model.pkl']

# %%
df3=pd.DataFrame(columns=['age','height'])

# %%
df3
# Out:
# Empty DataFrame
# Columns: [age, height]
# Index: []

# %%
dict={'age':20,'height':30}

# %%
df3.loc[0]=dict

# %%
df3
# Out:
#    age  height
# 0   20      30
